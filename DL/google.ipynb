# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Input

# %%
train_df = pd.read_csv('Google_Stock_Price_Train.xls')
test_df = pd.read_csv('Google_Stock_Price_Test.xls')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_df[['Open']].values)

plt.plot(train_scaled)
plt.title("Scaled Google Stock Prices")
plt.xlabel("Time")
plt.ylabel("Scaled Price")
plt.show()

# %%
time_step = 120
x_train, y_train = [], []

for i in range(time_step, train_scaled.shape[0]):
    x_train.append(train_scaled[i-time_step:i, 0])
    y_train.append(train_scaled[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
model = Sequential([
    Input(shape=(x_train.shape[1], 1)),
    LSTM(100, activation='tanh', return_sequences=True), Dropout(0.3),
    LSTM(100, activation='tanh'), Dropout(0.3),
    Dense(1)
])

model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 120, 100)            │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 120, 100)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100)                 │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 121,301 (473.83 KB)
#  Trainable params: 121,301 (473.83 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_train, epochs=200, batch_size=50, validation_split=0.05)
# Out:
# Epoch 1/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 0.2157 - val_loss: 0.0616
# Epoch 2/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0491 - val_loss: 0.0239
# Epoch 3/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0431 - val_loss: 0.0495
# Epoch 4/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0475 - val_loss: 0.0302
# Epoch 5/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0465 - val_loss: 0.0402
# Epoch 6/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0435 - val_loss: 0.0765
# Epoch 7/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0407 - val_loss: 0.0243
# Epoch 8/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0405 - val_loss: 0.0220
# Epoch 9/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0393 - val_loss: 0.0313
# Epoch 10/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0364 - val_loss: 0.0316
# Epoch 11/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0367 - val_loss: 0.0234
# Epoch 12/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0373 - val_loss: 0.0212
# Epoch 13/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0402 - val_loss: 0.0443
# Epoch 14/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0386 - val_loss: 0.0379
# Epoch 15/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0402 - val_loss: 0.0462
# Epoch 16/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0383 - val_loss: 0.0238
# Epoch 17/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0356 - val_loss: 0.0296
# Epoch 18/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0354 - val_loss: 0.0697
# Epoch 19/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0393 - val_loss: 0.0235
# Epoch 20/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0364 - val_loss: 0.0203
# Epoch 21/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0341 - val_loss: 0.0229
# Epoch 22/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step
200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0279 - val_loss: 0.0179
# Epoch 63/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0302 - val_loss: 0.0195
# Epoch 64/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0288 - val_loss: 0.0375
# Epoch 65/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0307 - val_loss: 0.0197
# Epoch 66/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0273 - val_loss: 0.0232
# Epoch 67/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0279 - val_loss: 0.0277
# Epoch 68/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0284 - val_loss: 0.0379
# Epoch 69/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0280 - val_loss: 0.0172
# Epoch 70/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0276 - val_loss: 0.0176
# Epoch 71/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0268 - val_loss: 0.0181
# Epoch 72/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0255 - val_loss: 0.0206
# Epoch 73/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0263 - val_loss: 0.0172
# Epoch 74/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0246 - val_loss: 0.0177
# Epoch 75/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0267 - val_loss: 0.0182
# Epoch 76/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0237 - val_loss: 0.0167
# Epoch 77/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0282 - val_loss: 0.0171
# Epoch 78/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0259 - val_loss: 0.0273
# Epoch 79/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0254 - val_loss: 0.0180
# Epoch 80/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0258 - val_loss: 0.0197
# Epoch 81/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0257 - val_loss: 0.0167
# Epoch 82/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0247 - val_loss: 0.0188
# Epoch 83/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0238 - val_loss: 0.0222
# Epoch 84/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0252 - val_loss: 0.0172
# Epoch 85/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0256 - val_loss: 0.0307
# Epoch 86/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0270 - val_loss: 0.0214
# Epoch 87/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0266 - val_loss: 0.0166
# Epoch 88/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0241 - val_loss: 0.0348
# Epoch 89/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0287 - val_loss: 0.0319
# Epoch 90/200
#  1/22 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0251

# %%
data = pd.concat((train_df['Open'], test_df['Open']), axis=0)
test_input = data[len(data) - len(test_df) - time_step:].values.reshape(-1, 1)

test_scaled = scaler.transform(test_input)

# %%
x_test = []
for i in range(time_step, test_scaled.shape[0]):
    x_test.append(test_scaled[i-time_step:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
y_pred = model.predict(x_test)
y_pred = scaler.inverse_transform(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step

# %%
y_test = test_df['Open'].values
output = model.evaluate(x_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 806.5510

# %%
plt.plot(y_test, color='red', label='Real Stock Price')
plt.plot(y_pred, color='blue', label='Predicted Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
